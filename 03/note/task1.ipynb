# %% [markdown]
# 教科書P.85　式(4.2)で表されるトーンカーブ変換（γ変換）を
# 実行するプログラムを作成しなさい。また、作成したプログラムを
# 適当な濃淡画像に適用し正しく実行されていることを
# 確認しなさい。

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np

# %%
im = Image.open('vim.png')

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=225x225 at 0x107B04090>

# %%
r=2

# %%
im_point = 255*((np.array(im)/255)**(1/r))

# %%
Image.fromarray(im_point .astype(np.uint8)).save('./task1.jpg')

# %%
gray_im = im.convert('L')

# %%
gray_img.show()

# %%
gray_point = np.array(gray_im)

# %%
gray_point .flatten()
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)
